# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('matches.csv')
type(data)    # --> pandas.core.frame.DataFrame
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
### basics attributes and functions

# preview data
data.head()   # --> give u top 5 rows of dataset
data.head(2)  # --> only give top 2 rows of dataset
data.tail()   # --> "" 
data.tail(3)  # --> ""

data.shape    # rows and cols

data.info()   #give info of every rows 

data.describe()    # work only on the interger cols
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755 entries, 0 to 754
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               755 non-null    int64
#  1   season           755 non-null    int64
#  2   city             748 non-null    object
#  3   date             755 non-null    object
#  4   team1            755 non-null    object
#  5   team2            755 non-null    object
#  6   toss_winner      755 non-null    object
#  7   toss_decision    755 non-null    object
#  8   result           755 non-null    object
#  9   dl_applied       755 non-null    int64
#  10  winner           751 non-null    object
#  11  win_by_runs      755 non-null    int64
#  12  win_by_wickets   755 non-null    int64
#  13  player_of_match  751 non-null    object
#  14  venue            755 non-null    object
#  15  umpire1          753 non-null    object
#  16  umpire2          753 non-null    object
# ...

# %%
# how to choose multiple col
type(data['winner']) # pandas.core.series.Series

data['winner']

data[['team1' , 'team2', 'winner']]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 750          Chennai Super Kings              Kings XI Punjab
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
data[['team1' , 'team2', 'winner']].shape
# Out:
# (755, 3)

# %%
### column wise data of a row
data.iloc[0]            
data.iloc[1:4]          # slicing 
data.iloc[2:9:2]        # equidistance concept 

data.iloc[:, [4, 5, 10]]    # fancy indexing
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 750          Chennai Super Kings              Kings XI Punjab
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
### fetch rows on a condition given 

mask = data['city'] == 'Hyderabad'
mask
type(mask)
mask.size

data[mask]    # only rows which fulfilling the mask cnd i.e. Hyderbad
# Out:
#         id  season       city        date                  team1  \
# 0        1    2017  Hyderabad  05-04-2017    Sunrisers Hyderabad
# 5        6    2017  Hyderabad  09-04-2017          Gujarat Lions
# 18      19    2017  Hyderabad  17-04-2017    Sunrisers Hyderabad
# 20      21    2017  Hyderabad  19-04-2017    Sunrisers Hyderabad
# 35      36    2017  Hyderabad  30-04-2017    Sunrisers Hyderabad
# ..     ...     ...        ...         ...                    ...
# 714  11310    2019  Hyderabad  06-04-2019         Mumbai Indians
# 725  11321    2019  Hyderabad  14-04-2019         Delhi Capitals
# 728  11324    2019  Hyderabad  17-04-2019    Chennai Super Kings
# 733  11329    2019  Hyderabad  21-04-2019  Kolkata Knight Riders
# 743  11339    2019  Hyderabad  29-04-2019    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
### extract data with multiple cnds  
mask1 = data['city'] == 'Hyderabad'
mask2 = data['date'] > '2010-01-01'

mask3 = data[mask1 & mask2]
mask3.shape[0]     # this mask size (numbers of rows)
mask3.size         # big
mask3.head()
# Out:
#     id  season       city        date                team1  \
# 35  36    2017  Hyderabad  30-04-2017  Sunrisers Hyderabad
# 58  59    2017  Hyderabad  21-05-2017       Mumbai Indians
# 65  66    2008  Hyderabad  22-04-2008      Deccan Chargers
# 67  68    2008  Hyderabad  24-04-2008      Deccan Chargers
# 79  80    2008  Hyderabad  25-05-2008      Deccan Chargers
#
#                           team2            toss_winner toss_decision  result  \
# 35        Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 58       Rising Pune Supergiant         Mumbai Indians           bat  normal
# 65             Delhi Daredevils        Deccan Chargers           bat  normal
# 67             Rajasthan Royals       Rajasthan Royals         field  normal
# 79  Royal Challengers Bangalore        Deccan Chargers           bat  normal
#
#     dl_applied                       winner  win_by_runs  win_by_wickets  \
# ...

# %%
### the_value_count
# - find the frequency in the data 
# - catergorial data is used 

data['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 108
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
### plotting (not specific) 
import matplotlib.pyplot as plt
# data['winner'].value_counts().plot(kind='bar')
data['winner'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='winner'>

# %%
data['toss_decision'].value_counts()
# data['toss_decision'].value_counts().plot(kind = "pie")
data['win_by_runs'].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
### part - 8 on series 
# index - value(can repeat)


myseries = data['winner'].value_counts()
myseries
myseries.values           # --> array([108, 100,  92,  84,  82,  75,  67,  58,  29,  13,  12,  10,  10, 6, 5])
myseries.index
myseries.head()
myseries.tail()
myseries['Mumbai Indians']

# find the top 5 teams who played the most matches 
data['team1'].value_counts() + data['team2'].value_counts()
# Out:
# Chennai Super Kings            163
# Deccan Chargers                 75
# Delhi Capitals                  16
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                176
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          178
# Mumbai Indians                 186
# Pune Warriors                   46
# Rajasthan Royals               147
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    180
# Sunrisers Hyderabad            108
# Name: count, dtype: int64

# %%
### part - 9 (sort_values)

(data['team1'].value_counts() + data['team2'].value_counts()).sort_values()
(data['team1'].value_counts() + data['team2'].value_counts()).sort_values(ascending = False)
data.sort_values('city', ascending = False)   # changes made are not fully reflect to data so next line 
data.sort_values('city', ascending = True, inplace = True)   # changes made are not fully reflect to data so next line 
data.head()

# mutltiple cols 
data.sort_values(['city', 'date'])
data.sort_values(['city', 'date'], ascending = [True, False])
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  29-04-2014             Rajasthan Royals
# 470  471    2014  Abu Dhabi  26-04-2014  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  26-04-2014              Kings XI Punjab
# 464  465    2014  Abu Dhabi  21-04-2014          Chennai Super Kings
# 460  461    2014  Abu Dhabi  18-04-2014          Sunrisers Hyderabad
# ..   ...     ...        ...         ...                          ...
# 468  469    2014        NaN  25-04-2014          Sunrisers Hyderabad
# 469  470    2014        NaN  25-04-2014               Mumbai Indians
# 466  467    2014        NaN  23-04-2014          Chennai Super Kings
# 461  462    2014        NaN  19-04-2014               Mumbai Indians
# 462  463    2014        NaN  19-04-2014        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
### part-10 (drop-duplicates)           

data.drop_duplicates(subset= ['city']).shape[0]
data.drop_duplicates(subset= ['city'])                     # no city repeat more than one time 
# data.drop_duplicates(subset= ['city'], inplace = True)   # made changes permanent

data.drop_duplicates(subset= ['city', 'season']).shape[0]
data.drop_duplicates('season', keep = 'last')
# Out:
#         id  season            city        date                   team1  \
# 272    273    2011          Mumbai  02-05-2011          Mumbai Indians
# 95      96    2008          Mumbai  14-05-2008     Chennai Super Kings
# 215    216    2010          Nagpur  10-04-2010     Chennai Super Kings
# 161    162    2009  Port Elizabeth  16-05-2009          Mumbai Indians
# 662   7920    2018            Pune  28-04-2018     Chennai Super Kings
# 12      13    2017          Rajkot  14-04-2017  Rising Pune Supergiant
# 444    445    2013          Ranchi  15-05-2013           Pune Warriors
# 536    537    2015   Visakhapatnam  22-04-2015     Sunrisers Hyderabad
# 312    313    2012   Visakhapatnam  07-04-2012     Chennai Super Kings
# 622    623    2016   Visakhapatnam  15-05-2016          Mumbai Indians
# 754  11414    2019   Visakhapatnam  10-05-2019          Delhi Capitals
# 476    477    2014             NaN  30-04-2014     Sunrisers Hyderabad
#
# ...

# %%
### groupby function 

sectors = company.groupby("Sector")
sectors
len(company)
len(sectors)
sectors.size()

sectors.first()
sectors.last()
sectors.groups
sectors.get_group('Apparel')
sectors.sum()
sectors.mean()
sectors["Revenues"].std().sort_values(ascending = False)

# %%
### isin()

# Solve a problem 
    # - find the most destructive death over batsman in the history of IPL
    # Criteria: 
      # 1. on basis of strike rate ....i.e. (no.s of runs / played balls) * 100
      # 2. Min batsman have played 200 balls in over 16 - 20 

death_over = dellivery[dellivery['over'] > 15]
all_batsman = death_over.groupby('batsman')['batsman_runs'].count() 
x = all_batsman > 200
batsman_list = all_batsman[x].index.tolist()       # as we only need names and converted to list 


# now for strike rate process
# calculate runs and balls played by above batsman
final = delivery[delivery['batsman'].isin(batsman_list)]
runs = final.groupby('batsman')["batsman_runs"].sum()
balls = final.groupby('batsman')["batsman_runs"].count()
sr = (runs/balls)*100
sr                                # got strike rate of all these players

# %%
### Merge 

# Solve a problem 
    # - find the orange cap person(having most runs in a IPL) ex 2008 - Name  

new = delivery.merge(match, left_on = 'match_id', right_on ='id')
new.groupby(['season', 'batsman'])['bats_man'].sum()       # mutli index series
