# %% [markdown]
# ## What is a CNN (Convolutional Neural Network)?

# %% [markdown]
# A CNN is a special type of neural network designed specifically for image and spatial data.
#
# Key idea:
# 👉 Exploit spatial structure (nearby pixels are related)
#
# Unlike ANN, CNN:
#
# * does not flatten images initially
# * preserves height × width × channels
# * learns local patterns first, then global patterns

# %% [markdown]
# ## Why NOT use ANN for Images?
# (a). Huge parameters
#
# (b). No spatial understanding
#
# (c). Overfitting
#
# (d). No translation invariance

# %% [markdown]
# ## Core CNN Layers (with intuition)
# (a). Convolution Layer
#
# (b). Activation Function (ReLU)
#
# (c). Pooling Layer
#
# (d). Fully Connected (FC) Layer
#
# (e). Softmax / Sigmoid

# %% [markdown]
# ## CNN Intuition (MOST IMPORTANT)
#
# How CNN understands images (layer by layer)
#
# 1. Early layers
#
# * detect edges, lines, corners
#
# 2. Middle layers
#
# * detect textures, patterns, parts
#
# 3. Deep layers
#
# * detect objects, faces, complex shapes
#
#
# 📌 This is called Hierarchical Feature Learning
#
# ```
# Pixels → edges → boundaries → shapes → objects
# ```

# %% [markdown]
# ## Additional / Advanced CNN Layers
# (a). Batch Normalization
#
# (b). Dropout
#
# (c). Padding
#
# (d). Stride
#
# (e). Dilated Convolution
#
# (f). Transposed Convolution (Deconvolution)

# %% [markdown]
# ## CNN Applications (Very Important for Exams & Interviews)
# 1. Image Classification
#
# 2. Object Localization
#
# 3. Object Detection
#
# 4. Image Segmentation
#
# 5. Face Recognition
#
# 6. Black & White → Color Images
#
# 7. 3D Body Movement / Pose Estimation
#
# 8. Medical Imaging
#
# 7. Why CNN Works So Well (One-Line Points)
# * Parameter efficiency
# * Spatial awareness
# * Translation invariance
# * Hierarchical learning
# * Better generalization

# %% [markdown]
#                                                      2

# %% [markdown]
# ## Introduction: CNN vs Visual Cortex

# %% [markdown]
# ## Human Visual Cortex (Overview)

# %% [markdown]
# ## Receptive Fields (Key Concept)

# %% [markdown]
# ## Hubel & Wiesel Cat Experiment (1960s)

# %% [markdown]
# ## CNN Intuition from Visual Cortex

# %% [markdown]
# ## Development: From Brain to CNN

# %% [markdown]
# ## Important Differences (Exam Trap)

# %% [markdown]
# ## Conclusion (Perfect Exam Answer)

# %% [markdown]
#                                                      3

# %% [markdown]
# ## What is Convolution (in CNN)?

# %% [markdown]
# ## Convolution Operation (Step-by-Step)

# %% [markdown]
# ## Mathematical Formula (VERY IMPORTANT)

# %% [markdown]
# ## Output Size Formula (EXAM FAVOURITE)

# %% [markdown]
# ## Filter Shape (Very Important)

# %% [markdown]
# ## Multiple Filters (Why & How)

# %% [markdown]
# ## Edge Detection Filters (IMPORTANT)
#
# (a) Vertical Edge Detection Filter
# (b) Horizontal Edge Detection Filter
# (c) Inclined / Diagonal Edge Detection
# (d) Straight Line Detection

# %% [markdown]
# ## CNN vs Hand-Crafted Filters

# %% [markdown]
# ## Intuition Summary (One-Liners)

# %% [markdown]
# ## One-Shot Exam Conclusion
#
#
# Convolution operation applies learnable filters over local regions of an image to extract spatial features such as edges and textures. Multiple filters detect different orientations like vertical, horizontal, and inclined edges, forming the basis of hierarchical feature learning in CNNs.
